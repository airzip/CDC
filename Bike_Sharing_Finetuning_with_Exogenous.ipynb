# %% [markdown]
# # Transportation Demand Forecasting with Granite Time Series - Zero-shot Inference and Fine-tuning with Exogenous Inputs
#
# TinyTimeMixers (TTMs) are compact pre-trained models for Multivariate Time-Series Forecasting, open-sourced by IBM Research. With less than 1 Million parameters, TTM introduces the notion of the first-ever "tiny" pre-trained models for Time-Series Forecasting. TTM outperforms several popular benchmarks demanding billions of parameters in zero-shot and few-shot forecasting and can easily be fine-tuned for multivariate forecasts.
#
# In this recipe, we cover zero-shot forecasting, as well as fine-tuning. This example makes use of the Kaggle bike sharing [dataset](https://www.kaggle.com/datasets/lakshmi25npathi/bike-sharing-dataset) which contains bikes rental demand with weather and seasonal information.

# %% [markdown]
# ## Setting Up

# %% [markdown]
# ### Install the TSFM Library
#
# The [granite-tsfm library](https://github.com/ibm-granite/granite-tsfm) provides utilities for working with Time Series Foundation Models (TSFM). Here we retrieve and install a tested version of the library.

# %%
# Install the tsfm library
! pip install "granite-tsfm[notebooks]"
# Out:
# Collecting granite-tsfm[notebooks]
#   Downloading granite_tsfm-0.3.6-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<5,>=4.57.6 (from transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks])
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (4.8.3)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (1.3.1)
# Requirement already satisfied: urllib3>=1.26.19 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (2.5.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (2.0.2)
# Requirement already satisfied: torch<2.11,>=2.10 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (2.10.0+cu128)
# Requirement already satisfied: scikit-learn<1.8 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (1.6.1)
# Requirement already satisfied: pandas<4,>=2.3.3 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (2.3.3)
# Requirement already satisfied: filelock>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (3.24.3)
# Requirement already satisfied: einops>=0.7 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (0.8.2)
# Collecting jupyter (from granite-tsfm[notebooks])
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (3.10.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (8.1.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (5.24.1)
# Collecting kaleido (from granite-tsfm[notebooks])
#   Downloading kaleido-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]) (2.19.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=2.3.3->granite-tsfm[notebooks]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=2.3.3->granite-tsfm[notebooks]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4,>=2.3.3->granite-tsfm[notebooks]) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8->granite-tsfm[notebooks]) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8->granite-tsfm[notebooks]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8->granite-tsfm[notebooks]) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.11,>=2.10->granite-tsfm[notebooks]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<2.11,>=2.10->granite-tsfm[notebooks]) (1.3.5)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks])
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (4.67.3)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (1.12.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm[notebooks]) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm[notebooks]) (0.4.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm[notebooks]) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm[notebooks]) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm[notebooks]) (0.70.16)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->granite-tsfm[notebooks]) (2.1.1)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]) (4.0.15)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]) (3.0.16)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]) (6.4.5)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]) (6.17.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]) (3.6.8)
# Collecting choreographer>=1.3.0 (from kaleido->granite-tsfm[notebooks])
#   Downloading choreographer-1.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting logistro>=1.0.8 (from kaleido->granite-tsfm[notebooks])
#   Downloading logistro-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from kaleido->granite-tsfm[notebooks]) (3.11.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->granite-tsfm[notebooks]) (9.1.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]) (1.78.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]) (5.29.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]) (3.1.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.0->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (5.9.5)
# Requirement already satisfied: platformdirs>=4.3.6 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido->granite-tsfm[notebooks]) (4.9.2)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido->granite-tsfm[notebooks]) (3.20.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->granite-tsfm[notebooks]) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->granite-tsfm[notebooks]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->granite-tsfm[notebooks]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets->granite-tsfm[notebooks]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets->granite-tsfm[notebooks]) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (4.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5,>=4.57.6->transformers[torch]<5,>=4.57.6->granite-tsfm[notebooks]) (3.4.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.11,>=2.10->granite-tsfm[notebooks]) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->granite-tsfm[notebooks]) (3.0.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->granite-tsfm[notebooks]) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->granite-tsfm[notebooks]) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->granite-tsfm[notebooks]) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->granite-tsfm[notebooks]) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->granite-tsfm[notebooks]) (6.5.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter->granite-tsfm[notebooks]) (5.9.1)
# Requirement already satisfied: jupyterlab-server~=2.19 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]) (2.28.0)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]) (2.12.5)
# Requirement already satisfied: jupyter-ydoc~=0.2.4 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]) (0.2.5)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]) (0.8.0)
# Requirement already satisfied: nbclassic in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]) (1.3.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]) (25.1.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]) (5.10.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]) (0.24.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (0.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (6.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (1.5.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (4.13.5)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]) (0.5.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->granite-tsfm[notebooks]) (1.22.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (0.8.6)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.5.4)
# Requirement already satisfied: overrides in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (7.7.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (1.9.0)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.9.3)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.8.4)
# Requirement already satisfied: y-py<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-ydoc~=0.2.4->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.6.2)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server~=2.19->jupyterlab->jupyter->granite-tsfm[notebooks]) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server~=2.19->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server~=2.19->jupyterlab->jupyter->granite-tsfm[notebooks]) (4.26.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.2.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->jupyter->granite-tsfm[notebooks]) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets->granite-tsfm[notebooks]) (0.6.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter->granite-tsfm[notebooks]) (25.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter->granite-tsfm[notebooks]) (2.8.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->nbconvert->jupyter->granite-tsfm[notebooks]) (0.5.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab->jupyter->granite-tsfm[notebooks]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server~=2.19->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.1.1)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /usr/local/lib/python3.12/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (0.22.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->granite-tsfm[notebooks]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->granite-tsfm[notebooks]) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab->jupyter->granite-tsfm[notebooks]) (1.4.0)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 83.0 MB/s eta 0:00:00
# Downloading granite_tsfm-0.3.6-py3-none-any.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 14.6 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading kaleido-1.3.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 4.2 MB/s eta 0:00:00
# Downloading choreographer-1.3.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 22.3 MB/s eta 0:00:00
# Downloading logistro-2.0.1-py3-none-any.whl (8.6 kB)
# Installing collected packages: logistro, huggingface-hub, choreographer, kaleido, transformers, granite-tsfm, jupyter
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed choreographer-1.3.0 granite-tsfm-0.3.6 huggingface-hub-0.36.2 jupyter-1.1.1 kaleido-1.3.0 logistro-2.0.1 transformers-4.57.6

# %% [markdown]
# ### Import Packages
#
# From `tsfm_public`, we use the TinyTimeMixer model, forecasting pipeline, and plotting function. We also leverage a few components for the fine-tuning process.

# %%
import math
import os

import numpy as np
import pandas as pd
import torch
from torch.optim import AdamW
from torch.optim.lr_scheduler import OneCycleLR
from transformers import EarlyStoppingCallback, Trainer, TrainingArguments, set_seed

from tsfm_public import (
    TimeSeriesForecastingPipeline,
    TimeSeriesPreprocessor,
    TinyTimeMixerForPrediction,
    TrackingCallback,
    count_parameters,
    get_datasets,
)

from tsfm_public.toolkit.time_series_preprocessor import prepare_data_splits
from tsfm_public.toolkit.visualization import plot_predictions
# Out:
# 2026-05-20 17:52:51.780916: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779299572.125492      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779299572.233320      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779299573.154407      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779299573.154459      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779299573.154462      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779299573.154464      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ### Specify configuration variables
#
# We provide the names of the timestamp column and the target column to be predicted. The context length (in time steps) is set to match the pretrained model.

# %%
# TTM model branch
# Use "main" for 512-96 model
# Use "1024-96-r2" for 1024-96 model
# Use "512-96-ft-r2.1" for 512-96 r2.1 model
TTM_MODEL_REVISION = "512-96-ft-r2.1"
context_length = 512  # the max context length for the 512-96 model
prediction_length = 96  # the max prediction length for the 512-96 model

# Output directory for writing evaluation results.
OUT_DIR = "/tmp/ttm_results"

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Preparing the Data

# %% [markdown]
# ### Download the data
#
# We'll work with a [bike sharing datasety](https://archive.ics.uci.edu/dataset/275/bike+sharing+dataset) available from the UCI Machine learning repository. This dataset includes the count of rental bikes between the years 2011 and 2012 in the Capital bike share system with the corresponding weather and seasonal information.
#
# You can download the source code to a temporary directory by running the following commands. Later you can clean up any downloaded files by removing the `temp` folder.

# %%
# %%bash
# # curl https://archive.ics.uci.edu/static/public/275/$BIKE_SHARING -o $BIKE_SHARING && \
# BIKE_SHARING=bike+sharing+dataset.zip
# test -d temp || ( \
#   mkdir -p temp && \
#   cd temp && \
#     wget https://archive.ics.uci.edu/static/public/275/$BIKE_SHARING -O $BIKE_SHARING && \
#     unzip -o $BIKE_SHARING && \
#   rm -f $BIKE_SHARING && \
#   cd - \
# ) && ls -l temp/
# Out:
# Archive:  bike+sharing+dataset.zip
#   inflating: Readme.txt
#   inflating: day.csv
#   inflating: hour.csv
# /kaggle/working
# total 1200
# -rw-r--r-- 1 root root   57569 Dec 20  2013 day.csv
# -rw-r--r-- 1 root root 1156736 Dec 20  2013 hour.csv
# -rw-r--r-- 1 root root    5607 Dec 20  2013 Readme.txt
# --2026-05-20 17:53:29--  https://archive.ics.uci.edu/static/public/275/bike+sharing+dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘bike+sharing+dataset.zip’
#
#      0K .......... .......... .......... .......... ..........  167K
#     50K .......... .......... .......... .......... .......... 1.23M
#    100K .......... .......... .......... .......... ..........  453K
#    150K .......... .......... .......... .......... .......... 1.25M
#    200K .......... .......... .......... .......... ..........  453K
#    250K .......... .......... ...                               160M=0.6s
#
# 2026-05-20 17:53:30 (457 KB/s) - ‘bike+sharing+dataset.zip’ saved [279992]

# %%
DATA_FILE_PATH = "temp/hour.csv"

# %% [markdown]
# ### Read in the data
#
# We parse the CSV into a pandas dataframe, filling in any null values, and create a single window containing `context_length` time points. We ensure the timestamp column is a UTC datetime.

# %%
timestamp_column = "dteday"
target_columns = ["casual", "registered", "cnt"]

# Read in the data from the downloaded file.
input_df = pd.read_csv(DATA_FILE_PATH, parse_dates=[timestamp_column])

# Fix missing hours in original dataset date column
input_df[timestamp_column] = input_df[timestamp_column] + input_df.hr.apply(lambda x: pd.Timedelta(x, unit="hr"))

# Show the last few rows of the dataset.
input_df.tail()
# Out:
#        instant              dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375 2012-12-31 19:00:00       1   1    12  19        0        1
# 17375    17376 2012-12-31 20:00:00       1   1    12  20        0        1
# 17376    17377 2012-12-31 21:00:00       1   1    12  21        0        1
# 17377    17378 2012-12-31 22:00:00       1   1    12  22        0        1
# 17378    17379 2012-12-31 23:00:00       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %% [markdown]
# ### Plot a segment of the target series
#
# Here we inspect a preview of the target time series.

# %%
for target_column in target_columns:
    input_df.iloc[1000 : 1000 + 24 * 10].plot(x=timestamp_column, y=target_column, figsize=(20, 3))

# %% [markdown]
# ## Zero shot forecasting
#
# In the first part of this notebook, we focus on zero-shot inference of the targets only. This does not consider the relationships between the targets or any of the additional exogenous features in the dataset.

# %% [markdown]
# ### Split the data into training, validation, and testing sets
#
# We split the data into training, validation, and test sets. The training set is used to train the preprocessor, while the test set is used to evaluate the model performance.

# %%
split_config = {"train": 0.5, "test": 0.25}

train_df, valid_df, test_df = prepare_data_splits(input_df, context_length=context_length, split_config=split_config)
print(f"Data lengths: train = {len(train_df)}, val = {len(valid_df)}, test = {len(test_df)}")
# Out:
# Data lengths: train = 8689, val = 4858, test = 4856

# %% [markdown]
# ### Train the Preprocessor
#
# The preprocessor is trained on the training portion of the input data to learn the scaling factors. The scaling will be applied when we use the preprocess method of the time series preprocessor.

# %%
tsp = TimeSeriesPreprocessor(
    timestamp_column=timestamp_column,
    target_columns=target_columns,
    context_length=context_length,
    prediction_length=prediction_length,
    scaling=True,
    scaler_type="standard",
)

trained_tsp = tsp.train(train_df)

# %% [markdown]
# ### Generate zero-shot forecasts and evaluate
#
# To generate forecasts from the zero-shot model we first load the model and then configure a TimeSeriesForecastingPipeline. The pipeline is responsible for using the zero-shot model and the preprocessor to create forecasts and output the results.

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.57.6

# %%
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained(
    "ibm-granite/granite-timeseries-ttm-r2",  # Name of the model on HuggingFace.
    # revision=TTM_MODEL_REVISION,
    num_input_channels=len(target_columns),  # Number of input columns.
    trust_remote_code=True   # 添加此参数
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.24M [00:00<?, ?B/s]

# %%
pipeline = TimeSeriesForecastingPipeline(
    zeroshot_model,
    device=device,  # Specify your local GPU or CPU.
    feature_extractor=tsp,
    batch_size=512,
)

# Make a forecast on the target column given the input data.
zeroshot_forecast = pipeline(test_df)
zeroshot_forecast.head()
# Out:
# Device set to use cuda
#                dteday                                  casual_prediction  \
# 0 2012-07-02 07:00:00  [28.092826489891028, 39.88902209481888, 53.317...
# 1 2012-07-02 08:00:00  [37.58412322495612, 52.55803879285263, 65.7937...
# 2 2012-07-02 09:00:00  [65.09567418133706, 74.60190949129256, 82.0765...
# 3 2012-07-02 10:00:00  [78.48206848232307, 84.64023875810555, 86.5716...
# 4 2012-07-02 11:00:00  [81.02731401654638, 83.1163607681543, 85.02760...
#
#                                registered_prediction  \
# 0  [406.8381973738288, 281.53737298922044, 210.99...
# 1  [337.04373705868255, 242.36065260846058, 234.6...
# 2  [202.25404101842793, 201.0763203896783, 222.32...
# 3  [161.50106403818748, 192.41673863030476, 205.7...
# 4  [190.9787078701055, 204.29638967625436, 202.09...
#
#                                       cnt_prediction  \
# 0  [434.6446527033052, 318.19833721279736, 264.02...
# 1  [376.3038664324778, 292.50080067108354, 298.43...
# 2  [262.2255068918937, 270.08242506079046, 299.11...
# 3  [234.21507388342008, 271.7144282776969, 287.85...
# 4  [267.7991288397525, 283.80976398251016, 284.90...
#
#                                               casual  \
# 0  [19.999999784280565, 56.00000112850756, 70.000...
# 1  [56.00000112850756, 70.00000068788127, 66.9999...
# 2  [70.00000068788127, 66.99999913079048, 74.0000...
# 3  [66.99999913079048, 74.00000122259232, 74.0000...
# 4  [74.00000122259232, 74.00000122259232, 79.0000...
#
#                                           registered  \
# 0  [548.0000003818889, 239.0000059497106, 103.999...
# 1  [239.0000059497106, 103.99999997895328, 133.99...
# 2  [103.99999997895328, 133.9999992249458, 183.00...
# 3  [133.9999992249458, 183.0000023631694, 161.999...
# 4  [183.0000023631694, 161.99999938973104, 151.00...
#
#                                                  cnt
# 0  [567.9999950828334, 294.9999947295612, 173.999...
# 1  [294.9999947295612, 173.9999995756801, 200.999...
# 2  [173.9999995756801, 200.99999869175633, 257.00...
# 3  [200.99999869175633, 257.00000039775625, 235.9...
# 4  [257.00000039775625, 235.99999975800625, 229.9...

# %%
# Define some standard metrics.
def custom_metric(actual, prediction, column_header="results"):
    """Simple function to compute MSE"""
    a = np.asarray(actual.tolist())
    p = np.asarray(prediction.tolist())

    mask = ~np.any(np.isnan(a), axis=1)

    mse = np.mean(np.square(a[mask, :] - p[mask, :]))
    mae = np.mean(np.abs(a[mask, :] - p[mask, :]))
    return pd.DataFrame(
        {
            column_header: {
                "mean_squared_error": mse,
                "root_mean_squared_error": np.sqrt(mse),
                "mean_absolute_error": mae,
            }
        }
    )


custom_metric(zeroshot_forecast["cnt"], zeroshot_forecast["cnt_prediction"], "zero-shot forecast")
# Out:
#                          zero-shot forecast
# mean_squared_error             17635.200158
# root_mean_squared_error          132.797591
# mean_absolute_error               91.118466

# %% [markdown]
# ### Plot the Predictions vs. Actuals
#
# Plot the predictions vs. actuals for some random samples of time intervals in test dataset.

# %%
plot_predictions(
    input_df=test_df,
    predictions_df=zeroshot_forecast,
    freq="h",
    timestamp_column=timestamp_column,
    channel=target_columns[2],
    indices=[1974, 570, 722],
)

# %% [markdown]
# ## Fine-tuning the model
#
# In this part of this notebook, we focus on fine-tuning the pretrained model. We use the same data splits we defined above, but now include extra columns during the fine-tuning process.

# %% [markdown]
# ### Configure columns and preprocessor for fine-tuning
#
# We define the control columns or features whose values will be known into the future, and set up the time series preprocessor.

# %%
SEED = 42
set_seed(SEED)

control_columns = [
    "season",
    "yr",
    "mnth",
    "holiday",
    "weekday",
    "workingday",
    "weathersit",
    "temp",
    "atemp",
    "hum",
    "windspeed",
]

tsp = TimeSeriesPreprocessor(
    timestamp_column=timestamp_column,
    target_columns=target_columns,
    control_columns=control_columns,
    context_length=context_length,
    prediction_length=prediction_length,
    scaling=True,
    encode_categorical=False,
    scaler_type="standard",
)

# %% [markdown]
# ### Load the model for fine-tuning
# Similar to the zero-shot case, we load the TTM model available on [HuggingFace](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1). We have three target channels and several exogenous channels in this example and set configuration appropriately take this into accounts. Note that we also enable channel mixing in the decoder and forecast channel mising. This allows the decoder to be tuned to capture interactions between the channels as well as adjust the forecasts based on interactions with the exogenous.

# %%
finetune_forecast_model = TinyTimeMixerForPrediction.from_pretrained(
    "ibm-granite/granite-timeseries-ttm-r2",
    revision=TTM_MODEL_REVISION,
    num_input_channels=tsp.num_input_channels,
    decoder_mode="mix_channel",  # exog:  set to mix_channel for mixing channels in history
    prediction_channel_indices=tsp.prediction_channel_indices,
    exogenous_channel_indices=tsp.exogenous_channel_indices,
    fcm_context_length=1,  # exog: indicates lag length to use in the exog fusion. for Ex. if today sales can get affected by discount on +/- 2 days, mention 2
    fcm_use_mixer=True,  # exog: Try true (1st option) or false
    fcm_mix_layers=2,  # exog: Number of layers for exog mixing
    enable_forecast_channel_mixing=True,  # exog: set true for exog mixing
    fcm_prepend_past=True,  # exog: set true to include lag from history during exog infusion.
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.44M [00:00<?, ?B/s]
# Some weights of TinyTimeMixerForPrediction were not initialized from the model checkpoint at ibm-granite/granite-timeseries-ttm-r2 and are newly initialized: ['decoder.decoder_block.mixers.0.channel_feature_mixer.gating_block.attn_layer.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.gating_block.attn_layer.weight', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc1.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc1.weight', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc2.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.mlp.fc2.weight', 'decoder.decoder_block.mixers.0.channel_feature_mixer.norm.norm.bias', 'decoder.decoder_block.mixers.0.channel_feature_mixer.norm.norm.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.gating_block.attn_layer.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.gating_block.attn_layer.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc1.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc1.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc2.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.mlp.fc2.weight', 'decoder.decoder_block.mixers.1.channel_feature_mixer.norm.norm.bias', 'decoder.decoder_block.mixers.1.channel_feature_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.0.feature_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.0.patch_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.1.feature_mixer.norm.norm.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.gating_block.attn_layer.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.gating_block.attn_layer.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc1.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc1.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc2.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.mlp.fc2.weight', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.norm.norm.bias', 'head.fcm_block.exog_mixer.mixers.1.patch_mixer.norm.norm.weight', 'head.fcm_block.fcm_embedding.bias', 'head.fcm_block.fcm_embedding.weight', 'head.fcm_block.fcm_gating_block.attn_layer.bias', 'head.fcm_block.fcm_gating_block.attn_layer.weight', 'head.fcm_block.mlp.bias', 'head.fcm_block.mlp.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Freeze the TTM Backbone
#
# During fine-tuning we freeze the backbone and focus on tuning only the parameters in the decoder. This reduces the overall number of parameters being tuned and maintains what the encoder learned during pretraining.

# %%
print(
    "Number of params before freezing backbone",
    count_parameters(finetune_forecast_model),
)

# Freeze the backbone of the model
for param in finetune_forecast_model.backbone.parameters():
    param.requires_grad = False

# Count params
print(
    "Number of params after freezing the backbone",
    count_parameters(finetune_forecast_model),
)
# Out:
# Number of params before freezing backbone 867631
# Number of params after freezing the backbone 314693

# %% [markdown]
# ### Get the datasets for fine tuning
#
# We use the `get_datasets` function in conjunction with the time series preprocessor. We split the data into training, validation, and test sets. The training set is used to train the model, while the test set is used to evaluate its performance. Note that we inspect the `resolution_prefix_tuning` attribute of the model config to enable the frequency token if needed.

# %%
train_dataset, valid_dataset, test_dataset = get_datasets(
    tsp, input_df, split_config, use_frequency_token=finetune_forecast_model.config.resolution_prefix_tuning
)
print(f"Data lengths: train = {len(train_dataset)}, val = {len(valid_dataset)}, test = {len(test_dataset)}")
# Out:
# Data lengths: train = 8082, val = 4251, test = 4249

# %% [markdown]
# ### Set up a Trainer for Fine-tuning
#
# Configure a Trainer for use in fine-tuning and evaluating the model.

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# Important parameters
learning_rate = 0.000298  # 0.000298364724028334
num_epochs = 50  # Ideally, we need more epochs (try offline preferably in a gpu for faster computation)
batch_size = 64

print(f"Using learning rate = {learning_rate}")
finetune_forecast_args = TrainingArguments(
    output_dir=os.path.join(OUT_DIR, "output"),
    overwrite_output_dir=True,
    learning_rate=learning_rate,
    num_train_epochs=num_epochs,
    do_eval=True,
    eval_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    dataloader_num_workers=4,
    report_to=None,
    save_strategy="epoch",
    logging_strategy="epoch",
    save_total_limit=1,
    logging_dir=os.path.join(OUT_DIR, "logs"),  # Make sure to specify a logging directory
    load_best_model_at_end=True,  # Load the best model when training ends
    metric_for_best_model="eval_loss",  # Metric to monitor for early stopping
    greater_is_better=False,  # For loss
    use_cpu=device != "cuda",  # Remove when GPU is available
)

# Create the early stopping callback
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=10,  # Number of epochs with no improvement after which to stop
    early_stopping_threshold=0.0,  # Minimum improvement required to consider as improvement
)
tracking_callback = TrackingCallback()

# Optimizer and scheduler
optimizer = AdamW(finetune_forecast_model.parameters(), lr=learning_rate)
scheduler = OneCycleLR(
    optimizer,
    learning_rate,
    epochs=num_epochs,
    steps_per_epoch=math.ceil(len(train_dataset) / (batch_size)),
)

finetune_forecast_trainer = Trainer(
    model=finetune_forecast_model,
    args=finetune_forecast_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    callbacks=[early_stopping_callback, tracking_callback],
    optimizers=(optimizer, scheduler),
)
# Out:
# Using learning rate = 0.000298
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %% [markdown]
# ### Train the Model
#
# Here we train the model on the training data. This tunes only the weights in the decoder and output layers, as the other weights have been frozen, taking into account the interactions between all the channels.

# %%
# Fine tune
finetune_forecast_trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
#     <div>
#
#       <progress value='1472' max='3200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1472/3200 03:31 < 04:08, 6.94 it/s, Epoch 23/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.060500</td>
#       <td>1.432032</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.847800</td>
#       <td>1.057657</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.728000</td>
#       <td>0.923089</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.654500</td>
#       <td>0.879321</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.604500</td>
#       <td>0.854197</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.563600</td>
#       <td>0.823097</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.535900</td>
#       <td>0.792497</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.509800</td>
#       <td>0.767954</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.488500</td>
#       <td>0.731459</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.461800</td>
#       <td>0.701230</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.431300</td>
#       <td>0.666078</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.404200</td>
#       <td>0.652836</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.381100</td>
#       <td>0.645031</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.362400</td>
#       <td>0.652359</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.342900</td>
#       <td>0.659885</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.325800</td>
#       <td>0.666930</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.313900</td>
#       <td>0.667922</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.300800</td>
#       <td>0.675339</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.290600</td>
#       <td>0.673224</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.279200</td>
#       <td>0.680963</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.269300</td>
#       <td>0.689334</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.261000</td>
#       <td>0.698484</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.253600</td>
#       <td>0.700479</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
# [TrackingCallback] Mean Epoch Time = 6.546293787334276 seconds, Total Train Time = 213.9215121269226
# TrainOutput(global_step=1472, training_loss=0.4639548814815024, metrics={'train_runtime': 213.9229, 'train_samples_per_second': 1888.998, 'train_steps_per_second': 14.959, 'total_flos': 6931233320030208.0, 'train_loss': 0.4639548814815024, 'epoch': 23.0})

# %% [markdown]
# ### Evaluate the Model
#
# Evaluate the fine-tuned model on the test dataset.

# %%
# generate forecasts using the finetuned model
pipeline = TimeSeriesForecastingPipeline(
    finetune_forecast_model,
    device=device,  # Specify your local GPU or CPU.
    feature_extractor=tsp,
    batch_size=batch_size,
)

# Make a forecast on the target column given the input data.
finetune_forecast = pipeline(test_df)
finetune_forecast.head()
# Out:
# Device set to use cuda
#                dteday                                  casual_prediction  \
# 0 2012-07-02 07:00:00  [21.29808934184734, 37.707378606405705, 54.596...
# 1 2012-07-02 08:00:00  [27.84927060993722, 50.163469167692696, 65.639...
# 2 2012-07-02 09:00:00  [61.6376218375313, 74.66768916249399, 83.71450...
# 3 2012-07-02 10:00:00  [76.10958417945896, 82.44877918554175, 83.9446...
# 4 2012-07-02 11:00:00  [75.95202279198298, 79.09075587214677, 77.7870...
#
#                                registered_prediction  \
# 0  [440.69010927820517, 301.05527838800435, 210.3...
# 1  [410.65135452283306, 258.1838503710344, 249.93...
# 2  [184.49131065114818, 176.36421104220133, 223.1...
# 3  [151.12767077602965, 193.93021386131255, 214.2...
# 4  [198.38972337264155, 201.37358411143157, 198.4...
#
#                                       cnt_prediction  \
# 0  [467.6849932725241, 342.9115720134014, 269.475...
# 1  [397.22748935990126, 295.4234924609266, 321.13...
# 2  [232.37410105446475, 263.9983680981268, 334.46...
# 3  [233.06629447883495, 304.3217706869398, 328.73...
# 4  [288.7027315848395, 307.9281429437474, 292.045...
#
#                                               casual  \
# 0  [19.999999784280565, 56.00000112850756, 70.000...
# 1  [56.00000112850756, 70.00000068788127, 66.9999...
# 2  [70.00000068788127, 66.99999913079048, 74.0000...
# 3  [66.99999913079048, 74.00000122259232, 74.0000...
# 4  [74.00000122259232, 74.00000122259232, 79.0000...
#
#                                           registered  \
# 0  [548.0000003818889, 239.0000059497106, 103.999...
# 1  [239.0000059497106, 103.99999997895328, 133.99...
# 2  [103.99999997895328, 133.9999992249458, 183.00...
# 3  [133.9999992249458, 183.0000023631694, 161.999...
# 4  [183.0000023631694, 161.99999938973104, 151.00...
#
#                                                  cnt
# 0  [567.9999950828334, 294.9999947295612, 173.999...
# 1  [294.9999947295612, 173.9999995756801, 200.999...
# 2  [173.9999995756801, 200.99999869175633, 257.00...
# 3  [200.99999869175633, 257.00000039775625, 235.9...
# 4  [257.00000039775625, 235.99999975800625, 229.9...

# %%
custom_metric(finetune_forecast["cnt"], finetune_forecast["cnt_prediction"], "fine-tune forecast")
# Out:
#                          fine-tune forecast
# mean_squared_error             13798.536011
# root_mean_squared_error          117.467170
# mean_absolute_error               82.769571

# %% [markdown]
# ### Plot the Predictions vs. Actuals
#
# Plot the predictions vs. actuals for some random samples of time intervals in test dataset.

# %%
# plot
plot_predictions(
    input_df=test_df,
    predictions_df=finetune_forecast,
    freq="h",
    timestamp_column=timestamp_column,
    channel=target_columns[2],
    indices=[3532, 3526, 2497],
)

# %% [markdown]
# ## Making the Forecast

# %% [markdown]
# ### Create a forecasting pipeline with the fine-tuned model
#
# We extract the appropriate historical data (context) and future values of control variables, and then set up the forecasting pipeline with the model and time series preprocessor.
#
# We choose a context window near the end of the test dataset, while still leaving enough known data from which we extract the controls. This is meant to simulate the case where you have historical information for the inputs and also provide future values of the controls.

# %%
historical_df = test_df.iloc[-prediction_length - context_length : -prediction_length].copy()
controls_df = test_df.iloc[-prediction_length:][[timestamp_column] + control_columns].copy()

# generate forecasts using the finetuned model
pipeline = TimeSeriesForecastingPipeline(
    finetune_forecast_model,
    device=device,  # Specify your local GPU or CPU.
    feature_extractor=tsp,
)

# Make a forecast on the target column given the input data.
finetune_forecast = pipeline(historical_df, future_time_series=controls_df)
# Out:
# Device set to use cuda

# %%
finetune_forecast
# Out:
#                dteday                                  casual_prediction  \
# 0 2012-12-27 23:00:00  [7.6076496087819905, 5.900333040490562, 4.9530...
#
#                                registered_prediction  \
# 0  [53.77208547824339, 41.22644253625403, 22.8926...
#
#                                       cnt_prediction  \
# 0  [69.6369113225063, 56.39052662203163, 38.61709...
#
#                                               casual  \
# 0  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                           registered  \
# 0  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                                  cnt
# 0  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...

# %% [markdown]
# ### Plot predictions along with the historical data.
#
# The predicted series picks up where the historical data ends, and we can see that it predicts a continuation of the cyclical pattern.

# %%
# Pre-cast the timestamp to avoid future dtype inference changes
historical_df[timestamp_column] = pd.to_datetime(historical_df[timestamp_column])

# Plot the historical data and predicted series.
plot_predictions(
    input_df=historical_df,
    predictions_df=finetune_forecast,
    freq=tsp.freq,
    timestamp_column=timestamp_column,
    channel=target_columns[0],
)
plot_predictions(
    input_df=historical_df,
    predictions_df=finetune_forecast,
    freq=tsp.freq,
    timestamp_column=timestamp_column,
    channel=target_columns[1],
)

# %% [markdown]
# ## Links
# * Library: [Granite TSFM on Github](https://github.com/ibm-granite/granite-tsfm)
# * Model: [TinyTimeMixer on HuggingFace](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1)
# * Dataset: [Bike Sharing Dataset on Kaggle](https://www.kaggle.com/datasets/lakshmi25npathi/bike-sharing-dataset)
